# %% [markdown]
# Evalúa qué tan precisa fue la descripción del alojamiento en comparación con la realidad. Mide si las fotos, descripciones y características anunciadas coinciden con lo que el huésped encontró al llegar.

# %% [markdown]
# Review_scores_accuracy
#  - Tipo de dato
#  - Cantidad de nulos
#  - Cantidad de Vacios
#  - Cantidad de datos unicos
#  - Cantidad de datos totales

# %%
import pandas as pd

# Cargar únicamente la columna 'Review_scores_accuracy' del archivo CSV
file_path = "../0_Dataset/Listings.csv"
data = pd.read_csv(file_path, usecols=['review_scores_accuracy'], delimiter=',', encoding='latin-1')

# Verificar si la columna 'Review_scores_accuracy' existe en el DataFrame
if 'review_scores_accuracy' in data.columns:
    # Tipo de dato
    tipo_dato = data['review_scores_accuracy'].dtype
    
    # Cantidad de nulos
    cantidad_nulos = data['review_scores_accuracy'].isna().sum()
    
    # Cantidad de vacíos (considerando cadenas vacías)
    cantidad_vacios = (data['review_scores_accuracy'] == '').sum()
    
    # Cantidad de datos únicos
    cantidad_unicos = data['review_scores_accuracy'].nunique()
    
    # Cantidad de datos totales
    cantidad_totales = data['review_scores_accuracy'].shape[0]
    
    # Imprimir resultados
    print(f"Columna 'review_scores_accuracy':")
    print(f" - Tipo de dato: {tipo_dato}")
    print(f" - Cantidad de nulos: {cantidad_nulos}")
    print(f" - Cantidad de vacíos: {cantidad_vacios}")
    print(f" - Cantidad de datos únicos: {cantidad_unicos}")
    print(f" - Cantidad de datos totales: {cantidad_totales}")
else:
    print("La columna 'review_scores_accuracy' no existe en el DataFrame.")
print(data['review_scores_accuracy'].value_counts())
print(data['review_scores_accuracy'].unique())
# Out:
# Columna 'review_scores_accuracy':
#  - Tipo de dato: float64
#  - Cantidad de nulos: 91713
#  - Cantidad de vacíos: 0
#  - Cantidad de datos únicos: 9
#  - Cantidad de datos totales: 279712
# review_scores_accuracy
# 10.0    136390
# 9.0      37176
# 8.0       8712
# 6.0       1974
# 7.0       1795
# 2.0       1152
# 4.0        527
# 5.0        240
# 3.0         33
# Name: count, dtype: int64
# [10.  9.  8.  4.  7.  6.  5. nan  2.  3.]

# %% [markdown]
# Analisis Cuantitaivo con outliers :
# * Promedio
# * Min
# * Max
# * Desviacion Estandar
# * Q1
# * Q2
# * Q3
# * Q4
# * Mediana
# * Kurtosis
# * Skewness

# %%
# Cantidad de filas antes de aplicar el filtro
total_antes = data['review_scores_accuracy'].shape[0]

# Filtrar valores válidos: eliminar nulos y valores iguales a 0
valores_validos = data['review_scores_accuracy'].dropna()
valores_validos = valores_validos[valores_validos > 0]

# Cantidad de filas después de filtrar
total_despues = valores_validos.shape[0]

# Calcular cuántos valores se eliminaron (nulos o 0)
valores_dropeados = total_antes - total_despues

# Imprimir el resultado
print(f"Cantidad de valores eliminados (dropeados): {valores_dropeados}")

if not valores_validos.empty:
    # Cálculo de estadísticas en escala natural
    promedio = valores_validos.mean()
    minimo = valores_validos.min()
    maximo = valores_validos.max()
    desviacion = valores_validos.std()
    q1 = valores_validos.quantile(0.25)
    q2 = valores_validos.quantile(0.50)  # Mediana
    q3 = valores_validos.quantile(0.75)
    q4 = valores_validos.quantile(1.0)
    varianza = valores_validos.var()
    kurtosis = valores_validos.kurtosis()
    skewness = valores_validos.skew()

    # Mostrar resultados
    print("\nAnálisis Cuantitativo de 'review_scores_accuracy' (escala natural, excluyendo valores 0):")
    print(f" - Promedio: {promedio:.2f}")
    print(f" - Mínimo: {minimo}")
    print(f" - Máximo: {maximo}")
    print(f" - Desviación estándar: {desviacion:.2f}")
    print(f" - Q1 (25%): {q1}")
    print(f" - Q2 / Mediana (50%): {q2}")
    print(f" - Q3 (75%): {q3}")
    print(f" - Q4 (100%): {q4}")
    print(f" - Varianza: {varianza}")
    print(f" - Curtosis (Kurtosis): {kurtosis:.4f}")
    print(f" - Asimetría (Skewness): {skewness:.4f}")
else:
    print("No hay suficientes datos válidos para realizar un análisis cuantitativo.")
# Out:
# Cantidad de valores eliminados (dropeados): 91713
#
# Análisis Cuantitativo de 'review_scores_accuracy' (escala natural, excluyendo valores 0):
#  - Promedio: 9.57
#  - Mínimo: 2.0
#  - Máximo: 10.0
#  - Desviación estándar: 0.99
#  - Q1 (25%): 9.0
#  - Q2 / Mediana (50%): 10.0
#  - Q3 (75%): 10.0
#  - Q4 (100%): 10.0
#  - Varianza: 0.9818389988463977
#  - Curtosis (Kurtosis): 24.0542
#  - Asimetría (Skewness): -4.2133

# %% [markdown]
# Graficas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar únicamente la columna 'review_scores_accuracy' del archivo CSV


# Verificar si la columna 'review_scores_accuracy' existe en el DataFrame
if 'review_scores_accuracy' in data.columns:
    # Contar la frecuencia de cada valor y ordenar por índice (puntuación) de forma creciente
    value_counts = data['review_scores_accuracy'].value_counts().sort_index()

    # Crear el gráfico de barras
    plt.figure(figsize=(10, 6))
    value_counts.plot(kind='bar', color='skyblue', edgecolor='black')
    plt.title('Distribución de la valoración de descripción', fontsize=16)
    plt.xlabel('Valoración', fontsize=14)
    plt.ylabel('Frecuencia de valoraciones', fontsize=14)
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()

    # Mostrar el gráfico
    plt.show()
else:
    print("La columna 'review_scores_accuracy' no existe en el DataFrame.")

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Cargar únicamente la columna 'review_scores_accuracy' del archivo CSV


# Verificar si la columna 'review_scores_accuracy' existe en el DataFrame
if 'review_scores_accuracy' in data.columns:
    # Filtrar valores válidos (eliminar nulos)
    valores_validos = data['review_scores_accuracy'].dropna()

    # Crear el gráfico boxplot
    plt.figure(figsize=(8, 6))
    plt.boxplot(valores_validos, vert=False, patch_artist=True, boxprops=dict(facecolor='skyblue'))
    plt.title('Boxplot de valoración de descripción', fontsize=16)
    plt.xlabel('Valoración', fontsize=14)
    plt.grid(axis='x', linestyle='--', alpha=0.7)

    # Mostrar el gráfico
    plt.tight_layout()
    plt.show()
else:
    print("La columna 'review_scores_accuracy' no existe en el DataFrame.")
