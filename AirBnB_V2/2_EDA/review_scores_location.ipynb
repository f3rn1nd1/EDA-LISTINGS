# %% [markdown]
# Califica la ubicación del alojamiento. Considera factores como la cercanía a puntos de interés, transporte público, seguridad del barrio y precisión de la ubicación anunciada.

# %% [markdown]
# Review_scores_location
#  - Tipo de dato
#  - Cantidad de nulos
#  - Cantidad de Vacios
#  - Cantidad de datos unicos
#  - Cantidad de datos totales

# %%
import pandas as pd

# Cargar únicamente la columna 'Review_scores_accuracy' del archivo CSV
file_path = "../0_Dataset/Listings.csv"
data = pd.read_csv(file_path, usecols=['review_scores_location'], delimiter=',', encoding='latin-1')

# Verificar si la columna 'Review_scores_accuracy' existe en el DataFrame
if 'review_scores_location' in data.columns:
    # Tipo de dato
    tipo_dato = data['review_scores_location'].dtype
    
    # Cantidad de nulos
    cantidad_nulos = data['review_scores_location'].isna().sum()
    
    # Cantidad de vacíos (considerando cadenas vacías)
    cantidad_vacios = (data['review_scores_location'] == '').sum()
    
    # Cantidad de datos únicos
    cantidad_unicos = data['review_scores_location'].nunique()
    
    # Cantidad de datos totales
    cantidad_totales = data['review_scores_location'].shape[0]
    
    # Imprimir resultados
    print(f"Columna 'review_scores_location':")
    print(f" - Tipo de dato: {tipo_dato}")
    print(f" - Cantidad de nulos: {cantidad_nulos}")
    print(f" - Cantidad de vacíos: {cantidad_vacios}")
    print(f" - Cantidad de datos únicos: {cantidad_unicos}")
    print(f" - Cantidad de datos totales: {cantidad_totales}")
else:
    print("La columna 'review_scores_location' no existe en el DataFrame.")

print(data['review_scores_location'].value_counts())
print(data['review_scores_location'].unique())
# Out:
# Columna 'review_scores_location':
#  - Tipo de dato: float64
#  - Cantidad de nulos: 91775
#  - Cantidad de vacíos: 0
#  - Cantidad de datos únicos: 9
#  - Cantidad de datos totales: 279712
# review_scores_location
# 10.0    140495
# 9.0      35350
# 8.0       8465
# 6.0       1480
# 7.0       1151
# 2.0        635
# 4.0        234
# 5.0        120
# 3.0          7
# Name: count, dtype: int64
# [10.  9.  8.  6.  7. nan  2.  5.  4.  3.]

# %% [markdown]
# Analisis Cuantitaivo:
# * Promedio
# * Min
# * Max
# * Desviacion Estandar
# * Q1
# * Q2
# * Q3
# * Q4
# * Mediana
# * Kurtosis
# * Skewness

# %%
# Cantidad de filas antes de aplicar dropna
total_antes = data['review_scores_location'].shape[0]

# Filtrar valores válidos
valores_validos = data['review_scores_location'].dropna()

# Cantidad de filas después de aplicar dropna
total_despues = valores_validos.shape[0]

# Calcular cuántos valores se dropearon
valores_dropeados = total_antes - total_despues

# Imprimir el resultado
print(f"Cantidad de valores eliminados (dropeados): {valores_dropeados}")

if not valores_validos.empty:
    # Cálculo de estadísticas sin transformar a escala relativa
    promedio = valores_validos.mean()
    minimo = valores_validos.min()
    maximo = valores_validos.max()
    desviacion = valores_validos.std()
    varianza = valores_validos.var()
    q1 = valores_validos.quantile(0.25)
    q2 = valores_validos.quantile(0.50)  # Mediana
    q3 = valores_validos.quantile(0.75)
    q4 = valores_validos.quantile(1.0)
    mediana = valores_validos.median()
    kurtosis = valores_validos.kurtosis()
    skewness = valores_validos.skew()

    # Mostrar resultados
    print("\nAnálisis Cuantitativo de 'review_scores_location':")
    print(f" - Promedio: {promedio:.2f}")
    print(f" - Mínimo: {minimo}")
    print(f" - Máximo: {maximo}")
    print(f" - Desviación estándar: {desviacion:.2f}")
    print(f" - Varianza: {varianza:.2f}")
    print(f" - Q1 (25%): {q1}")
    print(f" - Q2 / Mediana (50%): {q2}")
    print(f" - Q3 (75%): {q3}")
    print(f" - Mediana: {mediana}")
    print(f" - Curtosis (Kurtosis): {kurtosis:.4f}")
    print(f" - Asimetría (Skewness): {skewness:.4f}")
else:
    print("No hay suficientes datos válidos para realizar un análisis cuantitativo.")
# Out:
# Cantidad de valores eliminados (dropeados): 91775
#
# Análisis Cuantitativo de 'review_scores_location':
#  - Promedio: 9.63
#  - Mínimo: 2.0
#  - Máximo: 10.0
#  - Desviación estándar: 0.83
#  - Varianza: 0.69
#  - Q1 (25%): 9.0
#  - Q2 / Mediana (50%): 10.0
#  - Q3 (75%): 10.0
#  - Mediana: 10.0
#  - Curtosis (Kurtosis): 28.3887
#  - Asimetría (Skewness): -4.3180

# %% [markdown]
# Grafica

# %%
import pandas as pd
import matplotlib.pyplot as plt



# Verificar si la columna 'review_scores_location' existe en el DataFrame
if 'review_scores_location' in data.columns:
    # Contar la frecuencia de cada valor y ordenar por índice (puntuación) de forma creciente
    value_counts = data['review_scores_location'].value_counts().sort_index()

    # Crear el gráfico de barras
    plt.figure(figsize=(10, 6))
    value_counts.plot(kind='bar', color='teal', edgecolor='black')
    plt.title('Distribución de valoraciones de ubiciones de alojamientos', fontsize=16)
    plt.xlabel('Valoración', fontsize=14)
    plt.ylabel('Frecuencia de valoraciones', fontsize=14)
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()

    # Mostrar el gráfico
    plt.show()
else:
    print("La columna 'review_scores_location' no existe en el DataFrame.")

# %%
import pandas as pd
import matplotlib.pyplot as plt



# Verificar si la columna 'review_scores_location' existe en el DataFrame
if 'review_scores_location' in data.columns:
    # Filtrar valores válidos (eliminar nulos)
    valores_validos = data['review_scores_location'].dropna()

    # Crear el gráfico boxplot
    plt.figure(figsize=(8, 6))
    plt.boxplot(valores_validos, vert=False, patch_artist=True, boxprops=dict(facecolor='teal'))
    plt.title('Boxplot de valoraciones de ubicacion de alojamientos', fontsize=16)
    plt.xlabel('Puntuación', fontsize=14)
    plt.grid(axis='x', linestyle='--', alpha=0.7)

    # Mostrar el gráfico
    plt.tight_layout()
    plt.show()
else:
    print("La columna 'review_scores_location' no existe en el DataFrame.")
